# %% [markdown]
# **Stacking - İstifleme**

# %%
import numpy as np

# %%
dizi1 = np.array([[1,2],[3,4]])
dizi1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
dizi2 = np.array([[-1,-2],[-3,-4]])
dizi2
# Out:
# array([[-1, -2],
#        [-3, -4]])

# %%
dizi_dikey = np.vstack((dizi1,dizi2))
dizi_dikey
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [-1, -2],
#        [-3, -4]])

# %%
dizi_yatay = np.hstack((dizi1,dizi2))
dizi_yatay
# Out:
# array([[ 1,  2, -1, -2],
#        [ 3,  4, -3, -4]])

# %%
#problem 2 boyutlu 2 satır ve 2 sütün olan 3 adet array oluştur,
#bunları yatayda ve dikeyde birleştir.

# %%
dizi3 = np.array([[1,3],[4,6]])
dizi3
# Out:
# array([[1, 3],
#        [4, 6]])

# %%
dizi_dikey_uclu = np.vstack((dizi1,dizi2,dizi3))
dizi_dikey_uclu
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [-1, -2],
#        [-3, -4],
#        [ 1,  3],
#        [ 4,  6]])

# %%
dizi_yatay_uclu = np.hstack((dizi1,dizi2,dizi3))
dizi_yatay_uclu
# Out:
# array([[ 1,  2, -1, -2,  1,  3],
#        [ 3,  4, -3, -4,  4,  6]])

# %% [markdown]
# **PANDAS**
#
# *   .csc, .txt bunların okunması ve import edilmesi için
# *   Preprocessing: verinin training için hazır hale getirilmesi
# *   EDA (Kesifsel Veri Analizi): outlier tespiti, feature extration, correlation....

# %%
import pandas as pd

# %% [markdown]
# **Dataframe Kavramı**

# %%
#dataframe
dictinoary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45, 66],
              "maas": [100.0, 150.0, 240.0, 350.0, 110.0, 220.0]}

dictinoary
# Out:
# {'isim': ['ali', 'veli', 'kenan', 'murat', 'ayse', 'hilal'],
#  'yas': [15, 16, 17, 33, 45, 66],
#  'maas': [100, 150, 240, 350, 110, 220]}

# %%
veri = pd.DataFrame(dictinoary) # dataframe = pandas degisken tipi
print(type(veri))
veri
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     isim  yas  maas
# 0    ali   15   100
# 1   veli   16   150
# 2  kenan   17   240
# 3  murat   33   350
# 4   ayse   45   110
# 5  hilal   66   220

# %%
veri.head() # ilk 5 satır
# Out:
#     isim  yas  maas
# 0    ali   15   100
# 1   veli   16   150
# 2  kenan   17   240
# 3  murat   33   350
# 4   ayse   45   110

# %%
veri.tail() # son 5 satır
# Out:
#     isim  yas  maas
# 1   veli   16   150
# 2  kenan   17   240
# 3  murat   33   350
# 4   ayse   45   110
# 5  hilal   66   220

# %%
veri.columns # veri sütunlarının adları
# Out:
# Index(['isim', 'yas', 'maas'], dtype='object')

# %%
# dataframe ile ilgili temel bilgilere ulaşmamız lazım
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   isim    6 non-null      object
#  1   yas     6 non-null      int64
#  2   maas    6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
veri.describe() # Veride bulunan numarik(sayısal) feature'ların(sütunların) temel istatistikleri
# Out:
#              yas        maas
# count   6.000000    6.000000
# mean   32.000000  195.000000
# std    20.474374   94.815611
# min    15.000000  100.000000
# 25%    16.250000  120.000000
# 50%    25.000000  185.000000
# 75%    42.000000  235.000000
# max    66.000000  350.000000

# %%
dictinoary2 = {"Calisan_adi": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "Calisan_yas": [15, 16, 17, 33, 45, 85],
               "Sigorta_durum":[0,1,1,0,1,0]}

dictinoary2
# Out:
# {'Calisan_adi': ['ali', 'veli', 'kenan', 'murat', 'ayse', 'hilal'],
#  'Calisan_yas': [15, 16, 17, 33, 45, 85],
#  'Sigorta_durum': [0, 1, 1, 0, 1, 0]}

# %%
veri2 = pd.DataFrame(dictinoary2)
veri2
# Out:
#   Calisan_adi  Calisan_yas  Sigorta_durum
# 0         ali           15              0
# 1        veli           16              1
# 2       kenan           17              1
# 3       murat           33              0
# 4        ayse           45              1
# 5       hilal           85              0

# %%
veri2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Calisan_adi    6 non-null      object
#  1   Calisan_yas    6 non-null      int64
#  2   Sigorta_durum  6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
veri2.columns
# Out:
# Index(['Calisan_adi', 'Calisan_yas', 'Sigorta_durum'], dtype='object')

# %%
veri2.tail()
# Out:
#   Calisan_adi  Calisan_yas  Sigorta_durum
# 1        veli           16              1
# 2       kenan           17              1
# 3       murat           33              0
# 4        ayse           45              1
# 5       hilal           85              0

# %%
veri2.head()
# Out:
#   Calisan_adi  Calisan_yas  Sigorta_durum
# 0         ali           15              0
# 1        veli           16              1
# 2       kenan           17              1
# 3       murat           33              0
# 4        ayse           45              1

# %%
veri2.describe()
# Out:
#        Calisan_yas  Sigorta_durum
# count     6.000000       6.000000
# mean     35.166667       0.500000
# std      27.161861       0.547723
# min      15.000000       0.000000
# 25%      16.250000       0.000000
# 50%      25.000000       0.500000
# 75%      42.000000       1.000000
# max      85.000000       1.000000

# %%
print(veri2)
# Out:
#   Calisan_adi  Calisan_yas  Sigorta_durum
# 0         ali           15              0
# 1        veli           16              1
# 2       kenan           17              1
# 3       murat           33              0
# 4        ayse           45              1
# 5       hilal           85              0

# %% [markdown]
# **İndeksleme ve Dilimleme**

# %%
dictinoary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45, 66],
              "maas": [100.0, 150.0, 240.0, 350.0, 110.0, 220.0]}
dictinoary

veri = pd.DataFrame(dictinoary)
veri
# Out:
#     isim  yas   maas
# 0    ali   15  100.0
# 1   veli   16  150.0
# 2  kenan   17  240.0
# 3  murat   33  350.0
# 4   ayse   45  110.0
# 5  hilal   66  220.0

# %%
veri["yas"]
# Out:
# 0    15
# 1    16
# 2    17
# 3    33
# 4    45
# 5    66
# Name: yas, dtype: int64

# %%
veri["maas"]
# Out:
# 0    100.0
# 1    150.0
# 2    240.0
# 3    350.0
# 4    110.0
# 5    220.0
# Name: maas, dtype: float64

# %%
# dataframe icerisine yeni sutun ekleme
veri["sehir"] = ["istanbul", "ankara", "izmir", "bursa", "izmir", "istanbul"]
veri
# Out:
#     isim  yas   maas     sehir
# 0    ali   15  100.0  istanbul
# 1   veli   16  150.0    ankara
# 2  kenan   17  240.0     izmir
# 3  murat   33  350.0     bursa
# 4   ayse   45  110.0     izmir
# 5  hilal   66  220.0  istanbul

# %%
veri["maas_yuzde_20_zamli"] = veri["maas"] + 20*veri["maas"]/100
veri
# Out:
#     isim  yas   maas     sehir  maas_yuzde_20_zamli
# 0    ali   15  100.0  istanbul                120.0
# 1   veli   16  150.0    ankara                180.0
# 2  kenan   17  240.0     izmir                288.0
# 3  murat   33  350.0     bursa                420.0
# 4   ayse   45  110.0     izmir                132.0
# 5  hilal   66  220.0  istanbul                264.0

# %%
# veri["yas"]
# loc = location kisaltma
veri.loc[:, "yas"] # row=satirlar, column = sutunlar
# Out:
# 0    15
# 1    16
# 2    17
# 3    33
# 4    45
# 5    66
# Name: yas, dtype: int64

# %%
veri.loc[0:2, "yas"]
# Out:
# 0    15
# 1    16
# 2    17
# Name: yas, dtype: int64

# %%
veri.columns
# Out:
# Index(['isim', 'yas', 'maas', 'sehir', 'maas_yuzde_20_zamli'], dtype='object')

# %%
veri.loc[0:2, ["isim", "maas", "sehir"]]
# Out:
#     isim   maas     sehir
# 0    ali  100.0  istanbul
# 1   veli  150.0    ankara
# 2  kenan  240.0     izmir

# %%
veri.loc[0:2, 'isim':'sehir']
# Out:
#     isim  yas   maas     sehir
# 0    ali   15  100.0  istanbul
# 1   veli   16  150.0    ankara
# 2  kenan   17  240.0     izmir

# %%
veri.iloc[0:2,1]
# Out:
# 0    15
# 1    16
# Name: yas, dtype: int64

# %%
veri.iloc[[2,4], [1,2]]
# Out:
#    yas   maas
# 2   17  240.0
# 4   45  110.0

# %%
veri["maas2"] = veri["maas"] + 10
veri
# Out:
#     isim  yas   maas     sehir  maas_yuzde_20_zamli  maas2
# 0    ali   15  100.0  istanbul                120.0  110.0
# 1   veli   16  150.0    ankara                180.0  160.0
# 2  kenan   17  240.0     izmir                288.0  250.0
# 3  murat   33  350.0     bursa                420.0  360.0
# 4   ayse   45  110.0     izmir                132.0  120.0
# 5  hilal   66  220.0  istanbul                264.0  230.0

# %%
cols = veri.columns.tolist()
cols
# Out:
# ['isim', 'yas', 'maas', 'sehir', 'maas_yuzde_20_zamli', 'maas2']

# %%
maas2_index = cols.index('maas2')
maas2_index
# Out:
# 5

# %%
cols.remove('maas2')
cols
# Out:
# ['isim', 'yas', 'maas', 'sehir', 'maas_yuzde_20_zamli']

# %%
cols.insert(1, 'maas2')  # maas2'yi yas'tan sonra ekleyin (index 2)

# %%
cols
# Out:
# ['isim', 'maas2', 'yas', 'maas', 'sehir', 'maas_yuzde_20_zamli']

# %%
veri = veri[cols]

# %%
veri
# Out:
#     isim  maas2  yas   maas     sehir  maas_yuzde_20_zamli
# 0    ali  110.0   15  100.0  istanbul                120.0
# 1   veli  160.0   16  150.0    ankara                180.0
# 2  kenan  250.0   17  240.0     izmir                288.0
# 3  murat  360.0   33  350.0     bursa                420.0
# 4   ayse  120.0   45  110.0     izmir                132.0
# 5  hilal  230.0   66  220.0  istanbul                264.0

# %%
dictinoary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45, 66],
              "maas": [100.0, 150.0, 240.0, 350.0, 110.0, 220.0]}
dictinoary

veri = pd.DataFrame(dictinoary)
veri
# Out:
#     isim  yas   maas
# 0    ali   15  100.0
# 1   veli   16  150.0
# 2  kenan   17  240.0
# 3  murat   33  350.0
# 4   ayse   45  110.0
# 5  hilal   66  220.0

# %%
"""
1) Murat 33
2) 45 110
  66 220
3) veli 45
"""
# Out:
# '\n1) Murat 33\n2) 45 110\n  66 220\n3) veli 45\n'

# %%
veri.loc[3, ["isim","yas"]]
# Out:
# isim    murat
# yas        33
# Name: 3, dtype: object

# %%
veri.loc[4:5, ["yas","maas"]]
# Out:
#    yas   maas
# 4   45  110.0
# 5   66  220.0

# %%
# Iloc ile
print(veri.iloc[3, 0:2]) # 1.sorunun cevabı.
print(veri.iloc[4:6, 1:3]) # 2.sorunun cevabı.
print(veri.iloc[1, 0], veri.iloc[4, 1]) # 3.Sorunun cevabı

print(veri.loc[3, "isim":"yas"]) # 1.sorunun cevabı.
print(veri.loc[4:6, "yas":"maas"]) # 2.sorunun cevabı.
print(veri.loc[1, "isim"], veri.loc[4, "yas"]) # 3.Sorunun cevabı
# Out:
# isim    murat
# yas        33
# Name: 3, dtype: object
#    yas   maas
# 4   45  110.0
# 5   66  220.0
# veli 45
# isim    murat
# yas        33
# Name: 3, dtype: object
#    yas   maas
# 4   45  110.0
# 5   66  220.0
# veli 45

# %% [markdown]
# **Filtreleme**

# %%
dictinoary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45, 66],
              "sehir": ["izmir","ankara","konya","ankara","ankara","antalya"]}
dictinoary

veri = pd.DataFrame(dictinoary)
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
filtre1 = veri["yas"] > 22
filtre1
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# Name: yas, dtype: bool

# %%
filtrelenmis_veri = veri[filtre1]
filtrelenmis_veri
# Out:
#     isim  yas    sehir
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
filtre2 = veri["sehir"] == "ankara"
veri[filtre2]
# Out:
#     isim  yas   sehir
# 1   veli   16  ankara
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
veri[filtre1 & filtre2]
# Out:
#     isim  yas   sehir
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
# veri.isim
filtre3 = veri["isim"] == "ali"
veri[filtre3]
# Out:
#   isim  yas  sehir
# 0  ali   15  izmir

# %%
np.bitwise_and(veri["yas"] > 22, veri["sehir"] == "ankara")
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
#filtre4 = veri["isim"] == "ali"
#veri[filtre4]
veri[veri["isim"] == "ali"]
# Out:
#   isim  yas  sehir
# 0  ali   15  izmir

# %%
filtered_veri = veri.loc[(veri["sehir"] == "ankara") & (veri["yas"] > 22)]
print(filtered_veri)
# Out:
#     isim  yas   sehir
# 3  murat   33  ankara
# 4   ayse   45  ankara

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
"""
1) yeni sutun: maas sutunu ekle
2) yeni sutun: yas/maas orani sutunu ekle
3) yas/maas sutunu icin ortalamayi print ettir
4) ankarada yasayanlarin ortalama yasini bul
5) ankarada yasayanlarin icinden en yuksek maas alani bul
"""
# Out:
# '\n1) yeni sutun: maas sutunu ekle\n2) yeni sutun: yas/maas orani sutunu ekle\n3) yas/maas sutunu icin ortalamayi print ettir\n4) ankarada yasayanlarin ortalama yasini bul\n5) ankarada yasayanlarin icinden en yuksek maas alani bul\n'

# %%
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
veri["maas"] = [100,200,300,400,500,600]
veri
# Out:
#     isim  yas    sehir  maas
# 0    ali   15    izmir   100
# 1   veli   16   ankara   200
# 2  kenan   17    konya   300
# 3  murat   33   ankara   400
# 4   ayse   45   ankara   500
# 5  hilal   66  antalya   600

# %%
veri["yas_maas"] = veri["yas"] / veri["maas"]
veri
# Out:
#     isim  yas    sehir  maas  yas_maas
# 0    ali   15    izmir   100  0.150000
# 1   veli   16   ankara   200  0.080000
# 2  kenan   17    konya   300  0.056667
# 3  murat   33   ankara   400  0.082500
# 4   ayse   45   ankara   500  0.090000
# 5  hilal   66  antalya   600  0.110000

# %%
np.mean(veri["yas_maas"])
# Out:
# 0.0948611111111111

# %%
veri["ulke"] = ["turkiye"]*len(veri)
veri
# Out:
#     isim  yas    sehir     ulke
# 0    ali   15    izmir  turkiye
# 1   veli   16   ankara  turkiye
# 2  kenan   17    konya  turkiye
# 3  murat   33   ankara  turkiye
# 4   ayse   45   ankara  turkiye
# 5  hilal   66  antalya  turkiye

# %%
# 4) ankarada yasayanlarin ortalama yasini bul
ankarada_yasayanlar = veri[veri["sehir"] == "ankara"]
ankarada_yasayanlar
# Out:
#     isim  yas   sehir  maas  yas_maas
# 1   veli   16  ankara   200    0.0800
# 3  murat   33  ankara   400    0.0825
# 4   ayse   45  ankara   500    0.0900

# %%
# 4) ankarada yasayanlarin ortalama yasini bul
ankarada_yasayanlar_yas = ankarada_yasayanlar["yas"]
ankarada_yasayanlar_yas
# Out:
# 1    16
# 3    33
# 4    45
# Name: yas, dtype: int64

# %%
# 4) ankarada yasayanlarin ortalama yasini bul
ort = np.mean(ankarada_yasayanlar_yas)
ort
# Out:
# 31.333333333333332

# %%
# 5) ankarada yasayanlarin icinden en yuksek maas alani bul
ankarada_yasayanlar = veri[veri["sehir"] == "ankara"]
ankarada_yasayanlar
# Out:
#     isim  yas   sehir  maas  yas_maas
# 1   veli   16  ankara   200    0.0800
# 3  murat   33  ankara   400    0.0825
# 4   ayse   45  ankara   500    0.0900

# %%
# 5) ankarada yasayanlarin icinden en yuksek maas alani bul
ankarada_yasayanlar_maas = ankarada_yasayanlar["maas"]
ankarada_yasayanlar_maas
# Out:
# 1    200
# 3    400
# 4    500
# Name: maas, dtype: int64

# %%
# 5) ankarada yasayanlarin icinden en yuksek maas alani bul

np.max(ankarada_yasayanlar_maas)
# Out:
# 500

# %%
# maximum maasi alanin adini bulalim
ankarada_yasayanlar
# Out:
#     isim  yas   sehir  maas  yas_maas
# 1   veli   16  ankara   200    0.0800
# 3  murat   33  ankara   400    0.0825
# 4   ayse   45  ankara   500    0.0900

# %%
dictionary = {"isim":["ali","veli","kenan", "murat","ayşe","hilal"],
              "yas" : [15,16,17,33,45,66],
              "sehir": ["İzmir", "Ankara", "Konya", "Ankara", "Ankara", "Antalya"]}
veri=pd.DataFrame(dictionary)
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    İzmir
# 1   veli   16   Ankara
# 2  kenan   17    Konya
# 3  murat   33   Ankara
# 4   ayşe   45   Ankara
# 5  hilal   66  Antalya

# %%
veri[veri["sehir"]=="Ankara"]["yas"].mean()
# Out:
# 31.333333333333332

# %%
"""
for dongusu kullanarak maximum maas alanin ismini bulalim
"""
# Out:
# '\nfor dongusu kullanarak maximum maas alanin ismini bulalim\n'

# %%
ankarada_yasayanlar.reset_index(drop=True, inplace=True)
ankarada_yasayanlar
# Out:
#     isim  yas   sehir  maas  yas_maas
# 0   veli   16  ankara   200    0.0800
# 1  murat   33  ankara   400    0.0825
# 2   ayse   45  ankara   500    0.0900

# %%
maks_maas = 0
maks_isim = ""
for i in range(len(ankarada_yasayanlar)):
    if ankarada_yasayanlar["maas"][i] > maks_maas:
        maks_maas = ankarada_yasayanlar["maas"][i]
        maks_isim = ankarada_yasayanlar["isim"][i]

print(maks_isim)
# Out:
# ayse

# %%
ankarada_yasayanlar.loc[ankarada_yasayanlar["maas"].idxmax(), "isim"]
# Out:
# 'ayse'

# %% [markdown]
# List Comprehansion: Liste Kavrama

# %%
import pandas as pd

# %%
dictionary = {"isim": ["ali", "veli", "kenan", "murat", "ayse", "hilal"],
              "yas": [15, 16, 17, 33, 45 , 66],
              "sehir": ["izmir", "ankara", "konya", "ankara", "ankara","antalya"]}
veri=pd.DataFrame(dictionary)
veri
# Out:
#     isim  yas    sehir
# 0    ali   15    izmir
# 1   veli   16   ankara
# 2  kenan   17    konya
# 3  murat   33   ankara
# 4   ayse   45   ankara
# 5  hilal   66  antalya

# %%
# insanlarin ortalama yasini bulalim
# bu yastan buyuk ve kucuk olanlari filtreleyelim
# buyuk olanlara yeni bir feature olusturarak buyu, kucuk olanlara ise kucuk yazalım

# %%
import numpy as np
# yas sutununu elde et
veri_yas = veri.yas
print(veri_yas)
# yas stununun ortalamasini bul
veri_yas_mean = np.mean(veri_yas)
print(f"veri_yas_mean: {veri_yas_mean}")
# for dongusu ile insanlarin yasini ortalamaya ile kiyasla
# eger yaslari kucuk ise bir listenini icerisine "kucuk" yazdir degilse(buyukse) "buyuk" yazdir
liste_yas_grubu = []
for i in range(len(veri_yas)):
  dummy_veri_yas = veri_yas[i]
  if veri_yas_mean > dummy_veri_yas:
    liste_yas_grubu.append("kucuk")
  else:
    liste_yas_grubu.append("buyuk")
print(liste_yas_grubu)
veri["yas_grubu"] = liste_yas_grubu
print(veri)
# Out:
# 0    15
# 1    16
# 2    17
# 3    33
# 4    45
# 5    66
# Name: yas, dtype: int64
# veri_yas_mean: 32.0
# ['kucuk', 'kucuk', 'kucuk', 'buyuk', 'buyuk', 'buyuk']
#     isim  yas    sehir yas_grubu
# 0    ali   15    izmir     kucuk
# 1   veli   16   ankara     kucuk
# 2  kenan   17    konya     kucuk
# 3  murat   33   ankara     buyuk
# 4   ayse   45   ankara     buyuk
# 5  hilal   66  antalya     buyuk

# %%
veri["yas_grubu2"] = ["kucuk" if veri_yas_mean > veri_yas[i] else "buyuk" for i in range(len(veri_yas))]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas  yas_10_yil_sonrasi
# 0    ali   15    izmir     kucuk      kucuk       75                  25
# 1   veli   16   ankara     kucuk      kucuk       32                  26
# 2  kenan   17    konya     kucuk      kucuk       85                  27
# 3  murat   33   ankara     buyuk      buyuk       66                  43
# 4   ayse   45   ankara     buyuk      buyuk       90                  55
# 5  hilal   66  antalya     buyuk      buyuk      330                  76

# %%
veri["YAS_GRUBU2"] = [i.upper() for i in veri.yas_grubu2]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas  yas_10_yil_sonrasi  \
# 0    ali   15    izmir     kucuk      kucuk       75                  25
# 1   veli   16   ankara     kucuk      kucuk       32                  26
# 2  kenan   17    konya     kucuk      kucuk       85                  27
# 3  murat   33   ankara     buyuk      buyuk       66                  43
# 4   ayse   45   ankara     buyuk      buyuk       90                  55
# 5  hilal   66  antalya     buyuk      buyuk      330                  76
#
#   YAS_GRUBU2
# 0      KUCUK
# 1      KUCUK
# 2      KUCUK
# 3      BUYUK
# 4      BUYUK
# 5      BUYUK

# %%
veri.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# problem definition: tum satirlara bakalim eger ankarada yasayan varsa, yasini x 2 , else yas x 5
# new_yas sutun olusturalim

veri["new_yas"] = [ veri.yas[i]*2 if veri.sehir[i] == "ankara" else veri.yas[i]*5 for i in range(len(veri))]
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas
# 0    ali   15    izmir     kucuk      KUCUK       75
# 1   veli   16   ankara     kucuk      KUCUK       32
# 2  kenan   17    konya     kucuk      KUCUK       85
# 3  murat   33   ankara     buyuk      BUYUK       66
# 4   ayse   45   ankara     buyuk      BUYUK       90
# 5  hilal   66  antalya     buyuk      BUYUK      330

# %%
def yas10YilSonrasi(age):
  output = age + 10
  return output

# %%
veri["yas_10_yil_sonrasi"]=veri.yas.apply(yas10YilSonrasi)
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas  yas_10_yil_sonrasi  \
# 0    ali   15    izmir     kucuk      kucuk       75                  25
# 1   veli   16   ankara     kucuk      kucuk       32                  26
# 2  kenan   17    konya     kucuk      kucuk       85                  27
# 3  murat   33   ankara     buyuk      buyuk       66                  43
# 4   ayse   45   ankara     buyuk      buyuk       90                  55
# 5  hilal   66  antalya     buyuk      buyuk      330                  76
#
#   YAS_GRUBU2
# 0      KUCUK
# 1      KUCUK
# 2      KUCUK
# 3      BUYUK
# 4      BUYUK
# 5      BUYUK

# %%
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas  yas_10_yil_sonrasi  \
# 0    ali   15    izmir     kucuk      kucuk       75                  25
# 1   veli   16   ankara     kucuk      kucuk       32                  26
# 2  kenan   17    konya     kucuk      kucuk       85                  27
# 3  murat   33   ankara     buyuk      buyuk       66                  43
# 4   ayse   45   ankara     buyuk      buyuk       90                  55
# 5  hilal   66  antalya     buyuk      buyuk      330                  76
#
#   YAS_GRUBU2
# 0      KUCUK
# 1      KUCUK
# 2      KUCUK
# 3      BUYUK
# 4      BUYUK
# 5      BUYUK

# %%
# [veri.yas[i]*2 if veri.sehir[i]=="ankara" else veri.yas[i]*5 for i in range(len(veri))]
def yasCarpim(df):
  if df.sehir == "ankara":
    return df.yas*2
  elif df.sehir == "izmir":
    return df.yas*3
  else:
    return df.yas*5

# %%
veri.apply(yasCarpim, axis=1)
# Out:
# 0     45
# 1     32
# 2     85
# 3     66
# 4     90
# 5    330
# dtype: int64

# %%
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas  yas_10_yil_sonrasi  \
# 0    ali   15    izmir     kucuk      kucuk       75                  25
# 1   veli   16   ankara     kucuk      kucuk       32                  26
# 2  kenan   17    konya     kucuk      kucuk       85                  27
# 3  murat   33   ankara     buyuk      buyuk       66                  43
# 4   ayse   45   ankara     buyuk      buyuk       90                  55
# 5  hilal   66  antalya     buyuk      buyuk      330                  76
#
#   YAS_GRUBU2
# 0      KUCUK
# 1      KUCUK
# 2      KUCUK
# 3      BUYUK
# 4      BUYUK
# 5      BUYUK

# %%
# dataframe de bulunan insanlarin isimlerinin uzunlugu == 5 ise yeni yasi 2 ile varpalim
# eger isim uzunlugu == 4 ise 3 ile carpalim else 4 ile carpalim
def nameLengeth(df):
  if len(df.isim)==5:
    return df.yas*2
  elif len(df.isim)==4:
    return df.yas*3
  else:
    return df.yas*4

veri["new_age3"] = veri.apply(nameLengeth, axis=1)
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas  yas_10_yil_sonrasi  \
# 0    ali   15    izmir     kucuk      kucuk       75                  25
# 1   veli   16   ankara     kucuk      kucuk       32                  26
# 2  kenan   17    konya     kucuk      kucuk       85                  27
# 3  murat   33   ankara     buyuk      buyuk       66                  43
# 4   ayse   45   ankara     buyuk      buyuk       90                  55
# 5  hilal   66  antalya     buyuk      buyuk      330                  76
#
#   YAS_GRUBU2  new_yas3  new_age3
# 0      KUCUK        60        60
# 1      KUCUK        48        48
# 2      KUCUK        34        34
# 3      BUYUK        66        66
# 4      BUYUK       135       135
# 5      BUYUK       132       132

# %%
def isimUzunlugu(kcy):
  if len(kcy.isim) == 5:
    return kcy.yas*2
  elif len(kcy.isim) == 4:
    return kcy.yas*3
  else:
    return kcy.yas*4
veri["new_yas3"] = veri.apply(isimUzunlugu, axis=1) # veriyi satir satir isim uzunluğuna gonder
veri
# Out:
#     isim  yas    sehir yas_grubu yas_grubu2  new_yas  yas_10_yil_sonrasi  \
# 0    ali   15    izmir     kucuk      kucuk       75                  25
# 1   veli   16   ankara     kucuk      kucuk       32                  26
# 2  kenan   17    konya     kucuk      kucuk       85                  27
# 3  murat   33   ankara     buyuk      buyuk       66                  43
# 4   ayse   45   ankara     buyuk      buyuk       90                  55
# 5  hilal   66  antalya     buyuk      buyuk      330                  76
#
#   YAS_GRUBU2  new_yas3  new_age3
# 0      KUCUK        60        60
# 1      KUCUK        48        48
# 2      KUCUK        34        34
# 3      BUYUK        66        66
# 4      BUYUK       135       135
# 5      BUYUK       132       132

# %% [markdown]
# **Birleştirme**

# %%
import pandas as pd
sozluk1 = {"isim": ["ali","veli"],
           "yas": [15,16]}
veri1 = pd.DataFrame(sozluk1)
veri1
# Out:
#    isim  yas
# 0   ali   15
# 1  veli   16

# %%
sozluk2 = {"isim": ["murat", "ayse"],
           "yas": [32, 33]}
veri2 = pd.DataFrame(sozluk2)
veri2
# Out:
#     isim  yas
# 0  murat   32
# 1   ayse   33

# %%
# concat
veri_dikey = pd.concat([veri1, veri2], axis=0)
veri_dikey
# Out:
#     isim  yas
# 0    ali   15
# 1   veli   16
# 0  murat   32
# 1   ayse   33

# %%
# concat
veri_yatay = pd.concat([veri1, veri2], axis = 1)
veri_yatay
# Out:
#    isim  yas   isim  yas
# 0   ali   15  murat   32
# 1  veli   16   ayse   33

# %%
sozluk1 = {"isim": ["ali", "veli"],
           "yas": [15, 16]}
veri1 = pd.DataFrame(sozluk1)
print(veri1)
sozluk3 = {"sehir": ["ankara", "istanbul"],
           "yas": [22, 23]}
veri3 = pd.DataFrame(sozluk3)
veri3
# Out:
#    isim  yas
# 0   ali   15
# 1  veli   16
#       sehir  yas
# 0    ankara   22
# 1  istanbul   23

# %%
veri_yatay = pd.concat([veri1, veri3], axis = 1)
veri_yatay
# Out:
#    isim  yas     sehir  yas
# 0   ali   15    ankara   22
# 1  veli   16  istanbul   23

# %%
# ortak olmayanları farklu sütun olarak birleştirmek
veri_dikey = pd.concat([veri1, veri3], axis = 0, ignore_index=True)
# veri_dikey.reset_index(drop=True, inplace=True)
veri_dikey
# Out:
#    isim  yas     sehir
# 0   ali   15       NaN
# 1  veli   16       NaN
# 2   NaN   22    ankara
# 3   NaN   23  istanbul

# %% [markdown]
# **Matplotlib**
#
# - Görselleştirme kütüphanesi

# %%
import pandas as pd
veri = pd.read_csv("Iris.csv")
veri
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
veri.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
veri.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
veri.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
veri.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Line Plot: Çizgi Grafiği

# %%
import matplotlib.pyplot as plt
# x ekseni, y ekseni, color, alpha (opacity)
plt.figure(figsize=(6,2)) # (genislik, yukseklik)
# line plot, (x ekseni, y ekseni, renk, saydamlik, etiket)
plt.plot(veri["Id"], veri["SepalLengthCm"], color = "#0000ff", alpha = 0.9, label = "SepalLengthCm Etiket") # line plot
plt.plot(veri["Id"], veri["PetalLengthCm"], color = "red", alpha = 0.9, label = "PetalLengthCm")
plt.title("İris Çiçeği Görselleştirme") # baslik
plt.xlabel("Id Labeli") # x ekseni etiketi
plt.ylabel("SepalLengthCm Labeli") # y ekseni etiketi
plt.grid(True) # ızgara gorunumu
plt.legend() # plt plot'un icerisinde yazan label'in gorunmesi icin gerekli
plt.show()

# %% [markdown]
# Scatter Plot

# %%
veri.Species.unique() # bir seri içerisinde farklı olan değerleri gösteriyor
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
veri_setosa = veri[veri.Species == 'Iris-setosa']
veri_versicolor = veri[veri.Species == 'Iris-versicolor']
veri_virginica = veri[veri.Species == 'Iris-virginica']

# %%
plt.figure(figsize = (6,2))
# scatter(x,y,renk,size, saydamlik)
plt.scatter(veri_setosa["SepalLengthCm"], veri_setosa["PetalLengthCm"], color = "black", s = 15, alpha = 0.7, label = "veri_setosa")
plt.scatter(veri_versicolor["SepalLengthCm"], veri_versicolor["PetalLengthCm"], color = "red", s = 15, alpha = 0.7, label = "veri_versicolor")
plt.scatter(veri_virginica["SepalLengthCm"], veri_virginica["PetalLengthCm"], color = "blue", s = 15, alpha = 0.7, label = "veri_virginica")
plt.title("İris Çiçeği Görselleştirme")
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalLengthCm")
plt.grid(True)
plt.legend()
plt.show()

# %%
# dataseti indir: https://github.com/prashant-kikani/breast-cancer-detection/blob/master/breast-cancer-data.csv
# read ile import et
# pandas ise temel veri analizini yap
# matplotlib ile line plot ve scatter plot cizdir
# özetle matplotlib başlığı altında yaptığımız her şey bu veri seti ile yap

# %%
import pandas as pd
data = pd.read_csv("breast-cancer-data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
# pandas ise temel veri analizini yap
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
# matplotlib ile line plot
import matplotlib.pyplot as plt
plt.plot(data.texture_mean, color = "red", alpha = 0.5, label  = "texture_mean")
plt.xlabel("x etiketi")
plt.ylabel("y etiketi")
plt.title("baslik")
plt.legend()
plt.show()

# %%
# matplotlib scatter plot cizdir: radius_mean vs area_mean
plt.scatter(data.radius_mean, data.area_mean, color = "blue", s = 15, alpha = 0.5)
plt.xlabel("radius_mean")
plt.ylabel("area_mean")
plt.title("baslik")
# Out:
# Text(0.5, 1.0, 'baslik')

# %% [markdown]
# **Histogram**

# %%
import pandas as pd
veri = pd.read_csv("Iris.csv")
veri
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
plt.figure()
plt.hist(veri["SepalLengthCm"], color = "red", alpha = 0.9, bins=20 , label = "SepalLengthCm")
plt.hist(veri["PetalLengthCm"], color = "blue", alpha = 0.9, bins=20 , label = "PetalLengthCm")

plt.ylabel("Frekans (Kaç adet olduğu)")
plt.xlabel("cm")
plt.legend()

# %% [markdown]
# Subplots: Alt plan grafiği

# %%
import pandas as pd
veri = pd.read_csv("Iris.csv")
veri
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
fig, ax = plt.subplots(2,1) # 2 satir, 1 sutun
fig.suptitle("Ana baslik")
ax[0].plot(veri.SepalLengthCm, color = "red") # ax'lerin sifirincisi ilk eksen birinci plot
ax[0].set_title("Sepal Length")
ax[0].set_xlabel("index")
ax[0].set_ylabel("cm")

ax[1].plot(veri.PetalLengthCm, color = "blue")
ax[1].set_title("Petal Length")
ax[1].set_xlabel("index")
ax[1].set_ylabel("cm")

fig.tight_layout()
fig.subplots_adjust(top = 0.85)
plt.show()

# %%
import matplotlib.pyplot as plt

# 2x2'lik bir grid içinde 4 alt grafik oluştur
plt.subplot(2, 2, 1) # 2 satir ve 2 sutundan olussun ve ben 1. plotu cizdiriyorum
plt.scatter([1, 2, 3, 4], [5, 6, 7, 8])
plt.title("Alt Grafik 1")

plt.subplot(2, 2, 2)
plt.plot([1, 2, 3, 4], [8, 7, 6, 5])
plt.title("Alt Grafik 2")

plt.subplot(2, 2, 3) # 2 satir ve 2 sutundan olussun ve ben 3. plotu cizdiriyorum
plt.hist([1, 2, 3, 4, 5, 6, 7, 8])
plt.title("Alt Grafik 3")

plt.subplot(2, 2, 4)
plt.plot([1, 2, 3, 4], [8, 7, 6, 5])
plt.title("Alt Grafik 4")

plt.show() # Grafikleri göster

# %% [markdown]
# **Alıştırma-1**

# %%
# dataseti indir: https://github.com/prashant-kikani/breast-cancer-detection/blob/master/breast-cancer-data.csv
# class'larin (target variable) diagnosis ayrilmasi
# 2,3 bir subplot cizdirelim
# ilk satirda     M için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)
# ikinici satirda B için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)

# %%
import pandas as pd
data = pd.read_csv("breast-cancer-data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
# class'larin (target variable) diagnosis ayrilmasi
m = data[data["diagnosis"] == "M"]
m.reset_index(drop=True, inplace=True)
b = data[data["diagnosis"] == "B"]
b.reset_index(drop=True, inplace=True)

# ilk satirda     M için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)
plt.subplot(2, 3, 1)
plt.scatter(m.radius_mean, m.texture_mean)

plt.subplot(2, 3, 2)
plt.hist(m.radius_mean)

plt.subplot(2, 3, 3)
plt.plot(m.radius_mean)

# ikinici satirda B için scatter(radius_mean vs texture_mean), hist(radius_mean), plot(radius_mean)
plt.subplot(2, 3, 4)
plt.scatter(b.radius_mean, b.texture_mean)

plt.subplot(2, 3, 5)
plt.hist(b.radius_mean)

plt.subplot(2, 3, 6)
plt.plot(b.radius_mean)
